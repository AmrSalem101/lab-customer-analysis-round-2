# %%
import pandas as pd

# %%
file_path = r"C:\Users\amrsa\Documents\GitHub\lab-customer-analysis-round-2\files_for_lab\csv_files\marketing_customer_analysis.csv"
df=pd.read_csv(file_path)
df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
df.shape
# Out:
# (10910, 26)

# %%
df= df.drop(columns= "Unnamed: 0")

# %%
df
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
df.columns= df.columns.str.lower()
df.columns
# Out:
# Index(['customer', 'state', 'customer lifetime value', 'response', 'coverage',
#        'education', 'effective to date', 'employmentstatus', 'gender',
#        'income', 'location code', 'marital status', 'monthly premium auto',
#        'months since last claim', 'months since policy inception',
#        'number of open complaints', 'number of policies', 'policy type',
#        'policy', 'renew offer type', 'sales channel', 'total claim amount',
#        'vehicle class', 'vehicle size', 'vehicle type'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10279 non-null  object
#  2   customer lifetime value        10910 non-null  float64
#  3   response                       10279 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective to date              10910 non-null  object
#  7   employmentstatus               10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location code                  10910 non-null  object
#  11  marital status                 10910 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# customer                            0
# state                             631
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# vehicle type                     5482
# ...

# %%
df[df.duplicated()]
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 1134   BV86143         NaN             21034.018150      NaN     Basic
# 2799   YS94121         NaN              5645.396665      NaN     Basic
# 2805   BS34332         NaN              5557.934118      NaN     Basic
# 3590   GE63585         NaN              2420.711888      NaN     Basic
# 3877   GU42671     Arizona              6106.941981       No  Extended
# 4581   ID89933      Oregon              7255.577594       No  Extended
# 4992   GS76685  California             10408.968650      Yes     Basic
# 5734   AL78075      Oregon              3810.238281       No   Premium
# 5863   OJ33945      Oregon              8692.636838       No     Basic
# 6068   EP64069         NaN              5138.244998      NaN     Basic
# 6091   ID89933      Oregon              7255.577594       No  Extended
# 6116   RB49468         NaN              7511.660568      NaN     Basic
# ...

# %%
df=df.drop_duplicates()

# %%
numerical_df = df.select_dtypes(include = "number")
numerical_df
# Out:
#        customer lifetime value  income  monthly premium auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
categorical_df = df.select_dtypes(exclude = "number")
categorical_df
# Out:
#       customer       state response  coverage education effective to date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location code marital status     policy type  \
# ...

# %%
df.isna().sum()
# Out:
# customer                            0
# state                             614
# customer lifetime value             0
# response                          614
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           623
# months since policy inception       0
# number of open complaints         623
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     608
# vehicle size                      608
# vehicle type                     5465
# ...

# %%
categorical_df= categorical_df.drop(columns ="vehicle type" )

# %%
categorical_df
# Out:
#       customer       state response  coverage education effective to date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location code marital status     policy type  \
# ...

# %%
categorical_df =categorical_df.dropna()

# %%
categorical_df.isna().sum()
# Out:
# customer             0
# state                0
# response             0
# coverage             0
# education            0
# effective to date    0
# employmentstatus     0
# gender               0
# location code        0
# marital status       0
# policy type          0
# policy               0
# renew offer type     0
# sales channel        0
# vehicle class        0
# vehicle size         0
# dtype: int64

# %%
categorical_df
# Out:
#       customer       state response  coverage             education  \
# 0      DK49336     Arizona       No     Basic               College
# 1      KX64629  California       No     Basic               College
# 2      LZ68649  Washington       No     Basic              Bachelor
# 3      XL78013      Oregon      Yes  Extended               College
# 4      QA50777      Oregon       No   Premium              Bachelor
# ...        ...         ...      ...       ...                   ...
# 10904  QI63521      Nevada       No     Basic  High School or Below
# 10905  FE99816      Nevada       No   Premium              Bachelor
# 10906  KX53892      Oregon       No     Basic               College
# 10907  TL39050     Arizona       No  Extended              Bachelor
# 10908  WA60547  California       No   Premium               College
#
#       effective to date employmentstatus gender location code marital status  \
# ...

# %%
numerical_df
# Out:
#        customer lifetime value  income  monthly premium auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
numerical_df.isna().sum()
# Out:
# customer lifetime value            0
# income                             0
# monthly premium auto               0
# months since last claim          623
# months since policy inception      0
# number of open complaints        623
# number of policies                 0
# total claim amount                 0
# dtype: int64

# %%
numerical_df= numerical_df.dropna()
numerical_df
# Out:
#        customer lifetime value  income  monthly premium auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 5                  4745.181764   50549                    61
# ...                        ...     ...                   ...
# 10904             19228.463620       0                   187
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
numerical_df.isna().sum()
# Out:
# customer lifetime value          0
# income                           0
# monthly premium auto             0
# months since last claim          0
# months since policy inception    0
# number of open complaints        0
# number of policies               0
# total claim amount               0
# dtype: int64

# %%
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10250 entries, 0 to 10909
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer lifetime value        10250 non-null  float64
#  1   income                         10250 non-null  int64
#  2   monthly premium auto           10250 non-null  int64
#  3   months since last claim        10250 non-null  float64
#  4   months since policy inception  10250 non-null  int64
#  5   number of open complaints      10250 non-null  float64
#  6   number of policies             10250 non-null  int64
#  7   total claim amount             10250 non-null  float64
# dtypes: float64(4), int64(4)
# memory usage: 720.7 KB

# %%
categorical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9680 entries, 0 to 10908
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer           9680 non-null   object
#  1   state              9680 non-null   object
#  2   response           9680 non-null   object
#  3   coverage           9680 non-null   object
#  4   education          9680 non-null   object
#  5   effective to date  9680 non-null   object
#  6   employmentstatus   9680 non-null   object
#  7   gender             9680 non-null   object
#  8   location code      9680 non-null   object
#  9   marital status     9680 non-null   object
#  10  policy type        9680 non-null   object
#  11  policy             9680 non-null   object
#  12  renew offer type   9680 non-null   object
#  13  sales channel      9680 non-null   object
#  14  vehicle class      9680 non-null   object
#  15  vehicle size       9680 non-null   object
# ...

# %%
#trying to concatinate the two dataframes: categorical_df ,numerical_df
df1=pd.concat([categorical_df, numerical_df],axis = 1)
df1
######### wrong
# Out:
#       customer       state response  coverage education effective to date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10879      NaN         NaN      NaN       NaN       NaN               NaN
# 10883      NaN         NaN      NaN       NaN       NaN               NaN
# 10890      NaN         NaN      NaN       NaN       NaN               NaN
# 10894      NaN         NaN      NaN       NaN       NaN               NaN
# 10909      NaN         NaN      NaN       NaN       NaN               NaN
#
#       employmentstatus gender location code marital status  ...  \
# ...

# %%
filtered_df = df.iloc[1105:1236, :]
filtered_df
# Out:
#      customer       state  customer lifetime value response  coverage  \
# 1105  BU14748     Arizona              3618.686938       No  Extended
# 1106  FB71914  California             30205.012970       No  Extended
# 1107  SZ61347  California              5583.575264       No  Extended
# 1108  SS69401      Oregon              4841.057535       No     Basic
# 1109  CE72177  California              5461.548993       No     Basic
# ...       ...         ...                      ...      ...       ...
# 1232  WU14549      Nevada              4369.717940       No   Premium
# 1233  SF30642  California              8996.774075       No     Basic
# 1234  AG45299  California              8595.726399       No     Basic
# 1235  CN16311      Oregon              5476.527832       No     Basic
# 1236  IA63417         NaN              4001.519098      NaN   Premium
#
#                  education effective to date employmentstatus gender  income  \
# ...

# %%
df1= df1.dropna()
df1
# Out:
#       customer       state response  coverage             education  \
# 0      DK49336     Arizona       No     Basic               College
# 1      KX64629  California       No     Basic               College
# 2      LZ68649  Washington       No     Basic              Bachelor
# 3      XL78013      Oregon      Yes  Extended               College
# 6      IW72280  California       No     Basic                Doctor
# ...        ...         ...      ...       ...                   ...
# 10903  SU71163     Arizona       No     Basic               College
# 10904  QI63521      Nevada       No     Basic  High School or Below
# 10906  KX53892      Oregon       No     Basic               College
# 10907  TL39050     Arizona       No  Extended              Bachelor
# 10908  WA60547  California       No   Premium               College
#
#       effective to date employmentstatus gender location code marital status  \
# ...

# %%
df1= df1.reset_index(drop=True)
df1
# Out:
#      customer       state response  coverage             education  \
# 0     DK49336     Arizona       No     Basic               College
# 1     KX64629  California       No     Basic               College
# 2     LZ68649  Washington       No     Basic              Bachelor
# 3     XL78013      Oregon      Yes  Extended               College
# 4     IW72280  California       No     Basic                Doctor
# ...       ...         ...      ...       ...                   ...
# 9129  SU71163     Arizona       No     Basic               College
# 9130  QI63521      Nevada       No     Basic  High School or Below
# 9131  KX53892      Oregon       No     Basic               College
# 9132  TL39050     Arizona       No  Extended              Bachelor
# 9133  WA60547  California       No   Premium               College
#
#      effective to date employmentstatus gender location code marital status  \
# 0              2/18/11         Employed      M      Suburban        Married
# ...

# %%
df1['effective to date'] = pd.to_datetime(df1['effective to date'], errors = "coerce")
df1
# Out:
# C:\Users\amrsa\AppData\Local\Temp\ipykernel_30668\2693809803.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1['effective to date'] = pd.to_datetime(df1['effective to date'], errors = "coerce")
#      customer       state response  coverage             education  \
# 0     DK49336     Arizona       No     Basic               College
# 1     KX64629  California       No     Basic               College
# 2     LZ68649  Washington       No     Basic              Bachelor
# 3     XL78013      Oregon      Yes  Extended               College
# 4     IW72280  California       No     Basic                Doctor
# ...       ...         ...      ...       ...                   ...
# 9129  SU71163     Arizona       No     Basic               College
# 9130  QI63521      Nevada       No     Basic  High School or Below
# ...

# %%
df1.isna().sum()
# Out:
# customer                         0
# state                            0
# response                         0
# coverage                         0
# education                        0
# effective to date                0
# employmentstatus                 0
# gender                           0
# location code                    0
# marital status                   0
# policy type                      0
# policy                           0
# renew offer type                 0
# sales channel                    0
# vehicle class                    0
# vehicle size                     0
# customer lifetime value          0
# income                           0
# monthly premium auto             0
# months since last claim          0
# months since policy inception    0
# number of open complaints        0
# number of policies               0
# total claim amount               0
# dtype: int64

# %%
df1['month'] = df1['effective to date'].dt.month
df1
# Out:
#      customer       state response  coverage             education  \
# 0     DK49336     Arizona       No     Basic               College
# 1     KX64629  California       No     Basic               College
# 2     LZ68649  Washington       No     Basic              Bachelor
# 3     XL78013      Oregon      Yes  Extended               College
# 4     IW72280  California       No     Basic                Doctor
# ...       ...         ...      ...       ...                   ...
# 9129  SU71163     Arizona       No     Basic               College
# 9130  QI63521      Nevada       No     Basic  High School or Below
# 9131  KX53892      Oregon       No     Basic               College
# 9132  TL39050     Arizona       No  Extended              Bachelor
# 9133  WA60547  California       No   Premium               College
#
#      effective to date employmentstatus gender location code marital status  \
# 0           2011-02-18         Employed      M      Suburban        Married
# ...

# %%
first_quarter_data= df1[df1["month"].isin([1,2,3])]
first_quarter_data
# Out:
#      customer       state response  coverage             education  \
# 0     DK49336     Arizona       No     Basic               College
# 1     KX64629  California       No     Basic               College
# 2     LZ68649  Washington       No     Basic              Bachelor
# 3     XL78013      Oregon      Yes  Extended               College
# 4     IW72280  California       No     Basic                Doctor
# ...       ...         ...      ...       ...                   ...
# 9129  SU71163     Arizona       No     Basic               College
# 9130  QI63521      Nevada       No     Basic  High School or Below
# 9131  KX53892      Oregon       No     Basic               College
# 9132  TL39050     Arizona       No  Extended              Bachelor
# 9133  WA60547  California       No   Premium               College
#
#      effective to date employmentstatus gender location code marital status  \
# 0           2011-02-18         Employed      M      Suburban        Married
# ...

# %%
other_months_data = df1[~df1["month"].isin([1, 2, 3])]
other_months_data
# Out:
# Empty DataFrame
# Columns: [customer, state, response, coverage, education, effective to date, employmentstatus, gender, location code, marital status, policy type, policy, renew offer type, sales channel, vehicle class, vehicle size, customer lifetime value, income, monthly premium auto, months since last claim, months since policy inception, number of open complaints, number of policies, total claim amount, month]
# Index: []
#
# [0 rows x 25 columns]

# %%
#df which is before cleaning 
df
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
##Bonus 
def preprocess_data(df, date_column):
    # Display the original DataFrame shape
    print("Original DataFrame Shape:", df.shape)

    # Create a new DataFrame for processed data
    df2 = df.copy()

    # Standardize header names
    df2.columns = df2.columns.str.lower()

    # Identify numerical and categorical columns
    numerical_columns = df2.select_dtypes(include='number').columns
    categorical_columns = df2.select_dtypes(include='object').columns

    # Check and deal with NaN values
    df2[numerical_columns] = df2[numerical_columns].fillna(df2[numerical_columns].mean())
    df2[categorical_columns] = df2[categorical_columns].dropna()

    # Convert 'effective to date' to datetime and extract months
    df2[date_column] = pd.to_datetime(df2[date_column], format='%m/%d/%y', errors='coerce')
    df2['month'] = df2[date_column].dt.month

    # Filter data for the first quarter (January, February, and March)
    first_quarter_data = df2[df2['month'].isin([1, 2, 3])]
    first_quarter_data = first_quarter_data.reset_index(drop=True)

    display(first_quarter_data)
    df2.isna()
    return df2

# Example usage:
# df = ...  # Load your DataFrame here
# processed_df = preprocess_data(df, 'effective to date')

# %%
preprocess_data(df,"effective to date")
# Out:
# Original DataFrame Shape: (10873, 25)
#      customer       state  customer lifetime value response  coverage  \
# 0     LZ68649  Washington             14947.917300       No     Basic
# 1     XL78013      Oregon             22332.439460      Yes  Extended
# 2     HG93801     Arizona              5154.764074       No  Extended
# 3     KR82385  California              5454.587929       No     Basic
# 4     FH51383  California              5326.677654       No     Basic
# ...       ...         ...                      ...      ...       ...
# 4808  SU71163     Arizona              2771.663013       No     Basic
# 4809  QI63521      Nevada             19228.463620       No     Basic
# 4810  FE99816      Nevada             15563.369440       No   Premium
# 4811  KX53892      Oregon              5259.444853       No     Basic
# 4812  WA60547  California             11971.977650       No   Premium
#
#                  education effective to date employmentstatus gender  income  \
# ...
